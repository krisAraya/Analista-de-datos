# %% [markdown]
#    <center> <img src= "purchase.png" align = "center"/> </center>
#    <center> <h1 style = "color : #CD5C5C" > Metricas De Compras </h1> </center>

# %% [markdown]
# <h3 style= "color : #000000" > En el siguiente documento podremos entender como interactuo el cliente con la herramienta, para asi poder diferenciar cual seria el mayor punto de mejora de nuestro sitio web.
# Podremos tambien diferenciar cual es la mayor causa de cancelacion de ordenes asi como su razon principal </h3>

# %% [markdown]
# <h4 style= "color : #3498DB" > Brindaremos una serie de graficos los cuales podremos encontrar cuales fueron el total de ordenes obtenidas en las primeras 2 semanas del mes de Noviembre, tanto por pais como por el estado que se encuentran al momento de esta revision </h4>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib as mplt 
import seaborn as sns

# %%
cols = ["CREATION_DATE" "GATEWAY" "ACCOUNT" "STATUS" "SHOPPING_ASSISTANT" "ORDER_ID" "AMOUNT_QUOTED" "SHIPPER CLEAN" "Estado" "Razon"]

dfproyecto = pd.read_excel ("proyecto final.xlsx")

# %%
dfproyecto
# Out:
#            CREATION_DATE GATEWAY  ACCOUNT                        STATUS  \
# 0    2021-11-01 00:00:41     SJO   527654  In transit to Aeropost Miami
# 1    2021-11-01 00:01:58     SAL   124557  In transit to Aeropost Miami
# 2    2021-11-01 00:03:57     SAL    15756  In transit to Aeropost Miami
# 3    2021-11-01 00:08:36     SAL   110493  In transit to Aeropost Miami
# 4    2021-11-01 00:19:11     SCL   218973  In transit to Aeropost Miami
# ...                  ...     ...      ...                           ...
# 4621 2021-11-15 08:24:27     SJO   382646  Order successfully processed
# 4622 2021-11-15 08:26:14     SCL   297632                Pending Vendor
# 4623 2021-11-15 08:37:44     SCL   295492                Pending Vendor
# 4624 2021-11-15 08:37:53     SJO   457344                Pending Vendor
# 4625 2021-11-15 09:00:54     SJO    57755                           NaN
#
#        SHOPPING_ASSISTANT  ORDER_ID  AMOUNT_QUOTED SHIPPER CLEAN  \
# ...

# %%
dfproyecto. info ()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4626 entries, 0 to 4625
# Data columns (total 11 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   CREATION_DATE       4626 non-null   datetime64[ns]
#  1   GATEWAY             4626 non-null   object
#  2   ACCOUNT             4626 non-null   int64
#  3   STATUS              4623 non-null   object
#  4   SHOPPING_ASSISTANT  4626 non-null   object
#  5   ORDER_ID            4626 non-null   int64
#  6   AMOUNT_QUOTED       4626 non-null   float64
#  7   SHIPPER CLEAN       4626 non-null   object
#  8   Estado              4626 non-null   object
#  9   Razon               319 non-null    object
#  10  Unnamed: 10         2 non-null      object
# dtypes: datetime64[ns](1), float64(1), int64(2), object(7)
# memory usage: 397.7+ KB

# %%
dfproyecto["Estado"]. value_counts().plot(kind= "bar", title= "Estado actual de las ordenes")
# Out:
# <AxesSubplot:title={'center':'Estado actual de las ordenes'}>
